# %%
import pandas as pd 
import numpy as np

# %%
train = pd.read_csv("train.csv")
train.shape
# Out:
# (891, 12)

# %%
test = pd.read_csv("test.csv")
test.shape
# Out:
# (418, 11)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train['Survived'].value_counts() # 희생자가 더 많음
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
train.pivot_table('Survived',['Sex', 'Pclass', 'Embarked'])
train.pivot_table('Survived',['Sex','SibSp', 'Pclass'])
# Out:
#                      Survived
# Sex    SibSp Pclass
# female 0     1       0.979592
#              2       0.931818
#              3       0.592593
#        1     1       0.950000
#              2       0.892857
#              3       0.447368
#        2     1       1.000000
#              2       1.000000
#              3       0.571429
#        3     1       1.000000
#              2       1.000000
#              3       0.125000
#        4     3       0.333333
#        5     3       0.000000
#        8     3       0.000000
# male   0     1       0.329545
#              2       0.118421
#              3       0.129630
#        1     1       0.483871
#              2       0.259259
#              3       0.222222
#        2     1       0.500000
#              2       0.200000
#              3       0.125000
#        3     1       0.000000
#              3       0.000000
#        4     3       0.083333
#        5     3       0.000000
#        8     3       0.000000

# %%
test['Survived1'] = test[test['Sex']=='female'] == 'female', test['SibSp'] == 0
# ||test['SibSp'] == 1||test['SibSp'] == 2||test['SibSp'] == 3||test['Pclass'] == 1||test['Pclass'] == 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-03458fa261d2> in <module>()
# ----> 1 test['Survived1'] = test['Sex'] == 'female', test['SibSp'] == 0
#       2 # ||test['SibSp'] == 1||test['SibSp'] == 2||test['SibSp'] == 3||test['Pclass'] == 1||test['Pclass'] == 2
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# ...

# %%
test.loc[test['Sex'].isin(['female'])|| test[]]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6            898       3                               Connolly, Miss. Kate
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 15           907       2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 18           910       3                       Ilmakangas, Miss. Ida Livija
# 19           911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# ...

# %%
test['Sex'].isin(['female'])
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
# 5      False
# 6       True
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18      True
# 19      True
# 20     False
# 21     False
# 22      True
# 23     False
# 24      True
# 25     False
# 26      True
# 27     False
# 28     False
# 29     False
#        ...
# 388    False
# 389    False
# 390    False
# 391     True
# 392    False
# 393    False
# 394    False
# 395     True
# 396    False
# 397     True
# 398    False
# 399    False
# 400     True
# 401    False
# 402     True
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# 408     True
# 409     True
# 410     True
# 411     True
# 412     True
# 413    False
# 414     True
# 415    False
# 416    False
# 417    False
# Name: Sex, Length: 418, dtype: bool

# %%
# test[['Sex', 'SibSp', 'Pclass']][test.Sex == 'female'][test.SibSp < 3][test.Pclass <3]
# test['Survived2'] = test[test.columns][test.Sex == 'female'][test.SibSp < 3][test.Pclass <3]
index_list = test[test.columns][test.Sex == 'female'][test.SibSp < 3][test.Pclass <3].index
index_list = index_list.tolist()
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
Survived12 = []
for i in test.index:
    for j in index_list:
        if i != j:
        else:
            Survived12.append(1)

# %%
Survived12.count(0)
# Out:
# 32943

# %%
test['Survived12'] = Survived12
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-061f81432854> in <module>()
# ----> 1 test['Survived12'] = Survived12
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ...

# %%
test(index = index_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-8e2ceb9ac437> in <module>()
# ----> 1 test(index = index_list)
#
# TypeError: 'DataFrame' object is not callable

# %%
test['SibSp'] == 0
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
# 5       True
# 6       True
# 7      False
# 8       True
# 9      False
# 10      True
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19      True
# 20     False
# 21      True
# 22      True
# 23      True
# 24     False
# 25     False
# 26      True
# 27      True
# 28      True
# 29     False
#        ...
# 388     True
# 389    False
# 390     True
# 391     True
# 392     True
# 393     True
# 394    False
# 395    False
# 396     True
# 397    False
# 398     True
# 399     True
# 400     True
# 401    False
# 402     True
# 403     True
# 404    False
# 405     True
# 406    False
# 407    False
# 408     True
# 409    False
# 410     True
# 411    False
# 412     True
# 413     True
# 414     True
# 415     True
# 416     True
# 417    False
# Name: SibSp, Length: 418, dtype: bool

# %%
test.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
test['Survived'] = test['Sex'] == 'female'

# %%
test['Survived'] = test['Survived'].astype(int)

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q         0
# 1  47.0      1      0   363272   7.0000   NaN        S         1
# 2  62.0      0      0   240276   9.6875   NaN        Q         0
# 3  27.0      0      0   315154   8.6625   NaN        S         0
# 4  22.0      1      1  3101298  12.2875   NaN        S         1

# %%
test['Sex'] == 'female'
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
# 5      False
# 6       True
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14      True
# 15      True
# 16     False
# 17     False
# 18      True
# 19      True
# 20     False
# 21     False
# 22      True
# 23     False
# 24      True
# 25     False
# 26      True
# 27     False
# 28     False
# 29     False
#        ...
# 388    False
# 389    False
# 390    False
# 391     True
# 392    False
# 393    False
# 394    False
# 395     True
# 396    False
# 397     True
# 398    False
# 399    False
# 400     True
# 401    False
# 402     True
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# 408     True
# 409     True
# 410     True
# 411     True
# 412     True
# 413    False
# 414     True
# 415    False
# 416    False
# 417    False
# Name: Sex, Length: 418, dtype: bool

# %%
submission = test[['PassengerId', 'Survived']]

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
submission['Survived'] = submission['Survived'].astype(int) # 오류가 나게 됨 // 깊은복사 : copy, 얕은복사
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
submission = test[['PassengerId', 'Survived']].copy()

# %%
submission['Survived'] = submission['Survived'].astype(int)

# %%
submission['Survived'].dtype
# Out:
# dtype('int64')

# %%
# %mkdir submissions

# %%
submission.to_csv('submissions/submissions.csv', index=False)
